# %% [markdown]
# <a href="https://colab.research.google.com/github/grbarbosa3/Machine_learning/blob/master/KMeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/clustering.csv")
print("Tamanho do df: {}\n".format(df.shape))

df.head()
# Out:
# Tamanho do df: (381, 13)
#     Loan_ID Gender Married  ... Credit_History Property_Area Loan_Status
# 0  LP001003   Male     Yes  ...            1.0         Rural           N
# 1  LP001005   Male     Yes  ...            1.0         Urban           Y
# 2  LP001006   Male     Yes  ...            1.0         Urban           Y
# 3  LP001008   Male      No  ...            1.0         Urban           Y
# 4  LP001013   Male     Yes  ...            1.0         Urban           Y
#
# [5 rows x 13 columns]

# %%
from sklearn.cluster import KMeans

# %%
# Instanciar e escolher os hiperparamemtros

model = KMeans(n_clusters=2)
model2 = KMeans(n_clusters=4)

# Separar os dados

X = df[['ApplicantIncome', 'LoanAmount']]

# Padronizar os dados de treino

#scaler = StandardScaler().fit(X)
#X = scaler.transform(X)

# Fit do modelo

model.fit(X)
model2.fit(X)

# Fazer previsões em cima dos novos dados

y_pred = model.predict(X)
y_pred2 = model2.predict(X)

# %%
plt.scatter('ApplicantIncome', 'LoanAmount', data=df)
plt.show()

# %%
plt.scatter('ApplicantIncome', 'LoanAmount', data=df, c=y_pred, s=40, cmap='viridis')
plt.show()

# %%
plt.scatter('ApplicantIncome','LoanAmount', data=df, c=y_pred2, s=40, cmap='viridis')
plt.show()
